# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
iris = np.genfromtxt("C:\\Users\\BIT.L1-057\\Desktop\\iris.numeric", delimiter = ",")

# %%
iris = pd.DataFrame(iris)
iris
# Out:
#        0    1    2    3    4
# 0    5.1  3.5  1.4  0.2  1.0
# 1    4.9  3.0  1.4  0.2  1.0
# 2    4.7  3.2  1.3  0.2  1.0
# 3    4.6  3.1  1.5  0.2  1.0
# 4    5.0  3.6  1.4  0.2  1.0
# ..   ...  ...  ...  ...  ...
# 145  6.7  3.0  5.2  2.3  3.0
# 146  6.3  2.5  5.0  1.9  3.0
# 147  6.5  3.0  5.2  2.0  3.0
# 148  6.2  3.4  5.4  2.3  3.0
# 149  5.9  3.0  5.1  1.8  3.0
#
# [150 rows x 5 columns]

# %%
iris.columns = ["SL", "SW", "PL", "PW", "Species"]

# %%
colors = ["red", "blue", "yellow"]
for i in range(len(colors)):
    plt.scatter(iris[iris["Species"] == i+1]["SL"], iris[iris["Species"] == i+1]["PL"])
plt.show()

# %%
plt.boxplot(iris["SL"])
plt.show()

# %%
fig, ax = plt.subplots(nrows = 1, ncols = 2)
ax[0].hist(iris["SL"])
ax[1].hist(iris["PL"])
plt.show()

# %%
fig, ax = plt.subplots(nrows = 1, ncols = 2, sharex = True, sharey = True)
ax[0].hist(iris["SL"])
ax[1].hist(iris["PL"])
plt.show()

# %%
# 3

housing = pd.read_csv("C:\\Users\\BIT.L1-057\\Desktop\\housing.csv", header = 0, delimiter = ",")

# %%
housing
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
# ...

# %%
plt.scatter(housing["latitude"], housing["longitude"])

# %%
seasons = ["summer", "winter", "autumn", "spring"]
for i in seasons:
    plt.scatter(housing["latitude"], housing["longitude"], s = housing["population"]/25, c = housing["median_house_value"], cmap = i, alpha = 0.7)
    plt.xlabel("longitude")
    plt.ylabel("latitude")
    plt.colorbar()
    plt.show()
